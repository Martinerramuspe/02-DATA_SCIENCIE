# %%
# !pip install --upgrade requests pandas scikit-learn numpy joblib dill

# %%
# Out:
# 1.4.1.post1

# %%
from joblib import load
import requests
from io import BytesIO
import requests
from io import StringIO
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer, MinMaxScaler
from sklearn.pipeline import Pipeline
import numpy as np
import dill
from joblib import dump

# %%
# URL del archivo .joblib en GitHub
url = "https://github.com/Martinerramuspe/02-DATA_SCIENCIE/raw/main/01-TELECOM_CHURN_PROJECT/05-DESPLIEGUE/Streamlit_LocalFiles/Prepro01.joblib"

# Nombre del archivo local donde se guardará el archivo .joblib
nombre_archivo_local = "Prepro01.joblib"

# Descargar el archivo .joblib desde la URL y guardarlo localmente
respuesta = requests.get(url)
with open(nombre_archivo_local, "wb") as archivo_local:
    archivo_local.write(respuesta.content)

# Cargar el preprocesador desde el archivo local
Preprocesador = load(nombre_archivo_local)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-0ef9ba7dcbe2> in <cell line: 13>()
#      11
#      12 # Cargar el preprocesador desde el archivo local
# ---> 13 Preprocesador = load(nombre_archivo_local)
#
# /usr/local/lib/python3.10/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     656                     return load_compatibility(fobj)
#     657
# --> 658                 obj = _unpickle(fobj, filename, mmap_mode)
#     659     return obj
#
# /usr/local/lib/python3.10/dist-packages/joblib/numpy_pickle.py in _unpickle(fobj, filename, mmap_mode)
#     575     obj = None
#     576     try:
# --> 577         obj = unpickler.load()
#     578         if unpickler.compat_mode:
#     579             warnings.warn("The file '%s' has been generated with a "
#
# /usr/lib/python3.10/pickle.py in load(self)
# ...

# %%
# IMPORTAMOS MODELO ENTRENADO
url = "https://github.com/Martinerramuspe/02-DATA_SCIENCIE/raw/main/01-TELECOM_CHURN_PROJECT/05-DESPLIEGUE/Streamlit_LocalFiles/RandomForestClassifier.joblib"
respuesta = requests.get(url)
modelo = load(BytesIO(respuesta.content))

# %%
# IMPORTAMOS SET VIRGEN
file_id = "16ypxCIBr9wSGVEaXqWdZUfz9w4xzccwo"
download_link = f"https://drive.google.com/uc?id={file_id}"
response = requests.get(download_link)
csv_data = StringIO(response.text)
df = pd.read_csv(csv_data, encoding='utf-8')

# %%
pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 8.2 MB/s eta 0:00:00
# ...

# %%
import shap

# %%
expainer = shap.TreeExplainer(modelo)
