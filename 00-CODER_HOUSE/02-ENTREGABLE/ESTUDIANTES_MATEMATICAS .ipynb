# %% [markdown]
# ## **ENTREGABLE_01**

# %% [markdown]
# ## **ESTUDIANTES DE MATEMATICA**
# Los datos fueron obtenidos en una encuesta realizada a estudiantes de cursos de matemáticas  en la escuela secundaria. Contiene mucha información social, de género y de estudio interesante sobre los estudiantes. La idea es usarlos  para predecir la calificación final de los estudiantes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# LA FUENTE DE ESTE DATAFRAME ES KAGLE, SE CARGO EL .CSV EN REPOSITORIO DE GITHUB.
url = "https://github.com/Martinerramuspe/02-DATA_SCIENCIE/blob/main/00-CODER_HOUSE/00-DATASETS/student-mat.csv?raw=true"
df = pd.read_csv(url)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# DESCRIPCION DE VARIABLES:
# * escuela - escuela del estudiante (binario: 'GP' - Gabriel Pereira o 'MS' - Mousinho da Silveira)
# * sex - sexo del estudiante (binario: 'F' - femenino o 'M' - masculino)
# * edad - edad del estudiante (numérica: de 15 a 22)
# * dirección: tipo de dirección particular del estudiante (binario: 'U' - urbana o 'R' - rural)
# * famsize - tamaño de la familia (binario: 'LE3' - menor o igual a 3 o 'GT3' - mayor que 3)
# * Pstatus: estado de convivencia de los padres (binario: 'T' - viviendo juntos o 'A' - separados)
# * Medu - educación de la madre (numérica: 0 - ninguna, 1 - educación primaria (4to grado), 2 - 5to a 9no grado, 3 - educación secundaria o 4 - educación superior)
# * Fedu - educación del padre (numérica: 0 - ninguna, 1 - educación primaria (cuarto grado), 2 - quinto a noveno grado, 3 - educación secundaria o 4 - educación superior)
# * Mjob - trabajo de la madre (nominal: 'maestra', 'relacionado con la atención de salud', 'servicios' civiles (por ejemplo, administrativos o policiales), 'en_casa' u 'otros')
# * Fjob - trabajo del padre (nominal: 'maestro', 'relacionado con la atención de salud', 'servicios' civiles (por ejemplo, administrativos o policiales), 'en_casa' u 'otros')
# * motivo: motivo para elegir esta escuela (nominal: cerca de "casa", "reputación" de la escuela, preferencia de "curso" u "otro")
# * tutor - tutor del estudiante (nominal: 'madre', 'padre' u 'otro')
# * tiempo de viaje: tiempo de viaje de casa a la escuela (numérico: 1 - <15 min., 2 - 15 a 30 min., 3 - 30 min. a 1 hora, o 4 - >1 hora)
# * tiempo de estudio: tiempo de estudio semanal (numérico: 1 - <2 horas, 2 - 2 a 5 horas, 3 - 5 a 10 horas o 4 - >10 horas)
# * fracasos: número de fracasos de clases anteriores (numérico: n si 1<=n<3, de lo contrario 4)
# * schoolsup - apoyo educativo adicional (binario: sí o no)
# * famsup - apoyo educativo familiar (binario: sí o no)
# * pagado - clases extra pagadas dentro de la materia del curso (Matemáticas o Portugués) (binario: sí o no)
# * actividades - actividades extracurriculares (binario: sí o no)
# * guardería - asistió a la guardería (binario: sí o no)
# * superior - quiere cursar estudios superiores (binario: sí o no)
# * internet - Acceso a Internet en casa (binario: sí o no)
# * romántico - con una relación romántica (binario: sí o no)
# * famrel - calidad de las relaciones familiares (numérico: de 1 - muy malo a 5 - excelente)
# * tiempo libre - tiempo libre después de la escuela (numérico: de 1 - muy bajo a 5 - muy alto)
# * goout - salir con amigos (numérico: de 1 - muy bajo a 5 - muy alto)
# * Dalc - consumo de alcohol en jornada laboral (numérico: de 1 - muy bajo a 5 - muy alto)
# * Walc - consumo de alcohol durante el fin de semana (numérico: de 1 - muy bajo a 5 - muy alto)
# * salud - estado de salud actual (numérico: de 1 - muy malo a 5 - muy bueno)
# * ausencias - número de ausencias escolares (numérico: de 0 a 93)
# * G1 - calificación del primer período (numérica: de 0 a 20)
# G2 - calificación del segundo periodo (numérica: de 0 a 20)
# G3 - calificación final (numérica: de 0 a 20, objetivo de salida)

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
# PODEMOS OBSERVAR QUE EL DATAFRAME CUENTA CON 16 VARIABLES CUANTITATIVAS Y 17 VIARIABLES CUALITATIVAS.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
# DISTRIBUCION DE LOS DATOS NULOS SOBRE LAS VARIABLES.
plt.figure(figsize=(10, 8))
sns.heatmap(df.isnull(), cbar=False)
plt.show()
# SE PUEDE OBSERVAR QUE NO CONTAMOS CON DATOS NULOS DENTRO DE LOS DATAFRAME

# %%
# CORRELACION QUE EXISTE ENTRE VARIABLES CUANTITATIVAS.
plt.figure(figsize=(10, 8))
matriz = df.corr().round(2)
sns.heatmap(data=matriz, annot=True)
plt.show()
# SE PUEDE VER CORRELACION  DIRECTAS UN POCO FUERTES.
# Out:
# <ipython-input-6-d1cee68aa664>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz = df.corr().round(2)

# %% [markdown]
# SEGUN LO VISTO CON ANTERIORIDAD, TODAS LAS VARIABLES DEL DATAFRAME SON DE INTERES PARA EL MODELO PREDICTIVO, NO TENEMOS QUE EXCLUIR NINGUNA VARIABLE POR EL MOMENTO.

# %%
# GRAFICAMOS LAS RELACION ENTRE VARIABLES, PARA VER SI DISTRIBUCION CON RESPECTO A SUS EJES, Y SU DISTRIBUCION DE FORMA INDEPENDIENTE
sns.pairplot(df, diag_kind="kde")
plt.show()

# %% [markdown]
# ## **ENTREGABLE_02**

# %% [markdown]
# GRAFICOS CON SEABORN:

# %%
# GRAFICAMOS HISTOGRAMA DE LOS 3 TRIMESTRES (G1,G2 Y G3), DE FORMA PARALELA PARA OBSERVAR LA FORMA DE SI DISTRIBUCION.
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
# G1
sns.histplot(data=df, x='G1', bins=14, ax=axes[0],color="blue")
axes[0].set_xlabel('G1')
# G2
sns.histplot(data=df, x='G2', bins=14, ax=axes[1],color="green")
axes[1].set_xlabel('G2')
# G3
sns.histplot(data=df, x='G3', bins=14, ax=axes[2],color="red")
axes[2].set_xlabel('G3')
# Out:
# Text(0.5, 0, 'G3')

# %%
# SOLAPAMOS LOS HISTOGRAMAS PARA COMPARARLOS
sns.histplot(df,x='G1',bins=14,color="blue")
sns.histplot(df,x='G2',bins=14,color="green")
sns.histplot(df,x='G3',bins=14,color="red")
# OBSERVACION: SE PUEDE VER UNA DISOCIACION DEL G3 CON EL RESTO DE LOS TRIMESTRES.
# Out:
# <Axes: xlabel='G1', ylabel='Count'>

# %%
# REALIZAMOS SCATTERPLOT DE LOS TRES TRIMESTRES, ESTE TIPO DE GRAFICO NOS PERMITE ADENTRARNOS EN UN HISTOGRAMA.
columnas = ["G1", "G2", "G3"]
df_subconjunto = df[columnas]
sns.relplot(data=df_subconjunto, height=7, aspect=1.7)
# Estilo
sns.set_theme(style="darkgrid", context="paper")
plt.grid(False)
plt.show()
# OBSERVACION: EN EL TERCER TRIMESTRE HAY UNA GRAN CONCENTRACION DE NOTAS NULAS, A QUE SE DEBERA?

# %%
# LAS NOTAS DEL TRIMESTRE G1,G2 Y G3, SEPARADOS POR ESCUEL (SOLO HAY 2, GP Y MS), SIGUEN UNA MISMA DISTRIBUCION, PERO VARIA  SU CANTIDAD DE ALUMNOS.
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
sns.histplot(df,x='G1',hue='school',ax=axes[0])
sns.histplot(df,x='G2',hue='school',ax=axes[1])
sns.histplot(df,x='G3',hue='school',ax=axes[2])
# Out:
# <Axes: xlabel='G3', ylabel='Count'>

# %%
# UNA PREDOMINA SOBRE LA OTRA EN CUANTO A CANTIDA DE ALUMNOS
df.school.value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %% [markdown]
# GRAFICOS CON MATPLOTLIB:

# %%
# EJECUTAMOS SCATTERPLOT A G3, DE FORMA SOLITARIA PARA OBSERVAR SU COMPORTAMIENTOS
g1_data = df["G3"]
x = np.arange(len(g1_data))
plt.scatter(x, g1_data)
plt.show()

# %%
# CREAMOS BOX-PLOT DE LOS TRIMESTRES, PARA REALIZAR COMPARACIONES.
plt.boxplot([df["G1"],df["G2"],df["G3"]],vert=False,patch_artist=True)
plt.grid(True)
plt.title("boxplot")
plt.show()

# %%
# EJECUTAMOS BOX-PLOT PARA CADA ESCUELA, CORRESPONDIENTE AL PRIMER TRIMESTRE G3.
gp_data = df[df['school'] == 'GP']['G3']
ms_data = df[df['school'] == 'MS']['G3']
data_to_plot = [gp_data, ms_data]
plt.boxplot(data_to_plot, vert=False, patch_artist=True)
#eTIQUETAS
plt.yticks([1, 2], ['GP', 'MS'])
plt.title("Boxplot de G1 para las escuelas GP y MS")
plt.show()

# %%
sns.boxplot(data=df, x='school', y='G1')
plt.title("Boxplot de G1 para las escuelas GP y MS")
plt.show()
