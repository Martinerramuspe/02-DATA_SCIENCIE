# %% [markdown]
# # OBJETIVO: Buscar la mejor combinacion, para obtener el modelo mas eficiente.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# LA FUENTE DE ESTE DATAFRAME ES KAGLE, SE CARGO EL .CSV EN REPOSITORIO DE GITHUB.
url = "https://github.com/Martinerramuspe/02-DATA_SCIENCIE/blob/main/00-CODER_HOUSE/00-DATASETS/student-mat.csv?raw=true"
df = pd.read_csv(url)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.corr()["G1"]
# Out:
# <ipython-input-3-d74f358c6888>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()["G1"]
# age          -0.064081
# Medu          0.205341
# Fedu          0.190270
# traveltime   -0.093040
# studytime     0.160612
# failures     -0.354718
# famrel        0.022168
# freetime      0.012613
# goout        -0.149104
# Dalc         -0.094159
# Walc         -0.126179
# health       -0.073172
# absences     -0.031003
# G1            1.000000
# G2            0.852118
# G3            0.801468
# Name: G1, dtype: float64

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
df["G1"].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Parte 01: Uso de todas las variables.

# %%
X= df[['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences']]
y= df['G1']

# %%
import numpy as np

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
modelo = LinearRegression() # Asignamos nombre
modelo.fit(X_train,y_train) # aprendizaje
y_pred=modelo.predict(X_train) # prediccion
r2_score(y_train, y_pred)
# Out:
# 0.3451852203475664

# %%
# TEST
y_pred_test=modelo.predict(X_test)
r2_score(y_pred_test,y_test)
# Out:
# -1.4536545627343358

# %% [markdown]
# # Parte 02: Uso de 2 variables.

# %%
X= df[['Medu', 'Fedu']]
y= df['G1']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
modelo1 = LinearRegression() # Asignamos nombre
modelo1.fit(X_train,y_train) # aprendizaje
y_pred=modelo1.predict(X_train) # prediccion
r2_score(y_train, y_pred)
# Out:
# 0.04206588048691706

# %%
# TEST
y_pred_test=modelo1.predict(X_test)
r2_score(y_pred_test,y_test)
# Out:
# -18.780712704568682

# %% [markdown]
# # CONCLUSION:
# * El modelo no se ajusta al tipo de dato, es por eso que le rendimiento es muy bajo, aparte de las debiles correlaciones que no ayudam.
# * Realizamos una mala practica,que es testear el modelo con los test_sets, para medir su eficiencia.
